# %%
# !pip install opendatasets
# Out:
# Requirement already satisfied: opendatasets in c:\users\rosla\anaconda3\lib\site-packages (0.1.22)
# Requirement already satisfied: tqdm in c:\users\rosla\anaconda3\lib\site-packages (from opendatasets) (4.65.0)
# Requirement already satisfied: kaggle in c:\users\rosla\anaconda3\lib\site-packages (from opendatasets) (1.6.17)
# Requirement already satisfied: click in c:\users\rosla\anaconda3\lib\site-packages (from opendatasets) (7.1.2)
# Requirement already satisfied: six>=1.10 in c:\users\rosla\anaconda3\lib\site-packages (from kaggle->opendatasets) (1.16.0)
# Requirement already satisfied: certifi>=2023.7.22 in c:\users\rosla\anaconda3\lib\site-packages (from kaggle->opendatasets) (2024.2.2)
# Requirement already satisfied: python-dateutil in c:\users\rosla\anaconda3\lib\site-packages (from kaggle->opendatasets) (2.8.2)
# Requirement already satisfied: requests in c:\users\rosla\anaconda3\lib\site-packages (from kaggle->opendatasets) (2.31.0)
# Requirement already satisfied: python-slugify in c:\users\rosla\anaconda3\lib\site-packages (from kaggle->opendatasets) (8.0.4)
# Requirement already satisfied: urllib3 in c:\users\rosla\anaconda3\lib\site-packages (from kaggle->opendatasets) (2.0.7)
# Requirement already satisfied: bleach in c:\users\rosla\anaconda3\lib\site-packages (from kaggle->opendatasets) (4.1.0)
# Requirement already satisfied: colorama in c:\users\rosla\anaconda3\lib\site-packages (from tqdm->opendatasets) (0.4.6)
# Requirement already satisfied: packaging in c:\users\rosla\anaconda3\lib\site-packages (from bleach->kaggle->opendatasets) (23.1)
# Requirement already satisfied: webencodings in c:\users\rosla\anaconda3\lib\site-packages (from bleach->kaggle->opendatasets) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\rosla\anaconda3\lib\site-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rosla\anaconda3\lib\site-packages (from requests->kaggle->opendatasets) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rosla\anaconda3\lib\site-packages (from requests->kaggle->opendatasets) (3.4)

# %%
import opendatasets as od

# %%
dataset = 'https://www.kaggle.com/datasets/darrylljk/singapore-hdb-resale-flat-prices-2017-2024'

# %%
od.download(dataset)
# Out:
# Skipping, found downloaded files in ".\singapore-hdb-resale-flat-prices-2017-2024" (use force=True to force download)

# %%
import os

# %%
data_dir = '.\singapore-hdb-resale-flat-prices-2017-2024'

# %%
os.listdir(data_dir)
# Out:
# ['sg-resale-flat-prices-2017-onwards.csv']

# %%
import pandas as pd

# %%
hdb_df = pd.read_csv('sg-resale-flat-prices-2017-onwards.csv')
hdb_df
# Out:
#           month        town  flat_type block        street_name storey_range  \
# 0       2017-01  ANG MO KIO     2 ROOM   406  ANG MO KIO AVE 10     10 TO 12
# 1       2017-01  ANG MO KIO     3 ROOM   108   ANG MO KIO AVE 4     01 TO 03
# 2       2017-01  ANG MO KIO     3 ROOM   602   ANG MO KIO AVE 5     01 TO 03
# 3       2017-01  ANG MO KIO     3 ROOM   465  ANG MO KIO AVE 10     04 TO 06
# 4       2017-01  ANG MO KIO     3 ROOM   601   ANG MO KIO AVE 5     01 TO 03
# ...         ...         ...        ...   ...                ...          ...
# 181257  2024-06      YISHUN     5 ROOM  502B       YISHUN ST 51     10 TO 12
# 181258  2024-06      YISHUN     5 ROOM   865       YISHUN ST 81     07 TO 09
# 181259  2024-06      YISHUN  EXECUTIVE   723       YISHUN ST 71     10 TO 12
# 181260  2024-06      YISHUN  EXECUTIVE   826       YISHUN ST 81     10 TO 12
# 181261  2024-06      YISHUN  EXECUTIVE   826       YISHUN ST 81     04 TO 06
#
#         floor_area_sqm      flat_model  lease_commence_date  \
# 0                 44.0        Improved                 1979
# 1                 67.0  New Generation                 1978
# 2                 67.0  New Generation                 1980
# 3                 68.0  New Generation                 1980
# 4                 67.0  New Generation                 1980
# ...                ...             ...                  ...
# 181257           112.0        Improved                 2018
# 181258           122.0        Improved                 1988
# 181259           146.0      Maisonette                 1986
# 181260           146.0      Maisonette                 1988
# 181261           146.0      Maisonette                 1988
#
#            remaining_lease  resale_price
# 0       61 years 04 months      232000.0
# 1       60 years 07 months      250000.0
# 2       62 years 05 months      262000.0
# 3        62 years 01 month      265000.0
# 4       62 years 05 months      265000.0
# ...                    ...           ...
# 181257  92 years 08 months      738000.0
# 181258  62 years 10 months      680000.0
# 181259            61 years      790000.0
# 181260  62 years 08 months     1000000.0
# 181261  62 years 08 months     1000000.0
#
# [181262 rows x 11 columns]

# %%
# Finding out the content of the dataset 

hdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181262 entries, 0 to 181261
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   month                181262 non-null  object
#  1   town                 181262 non-null  object
#  2   flat_type            181262 non-null  object
#  3   block                181262 non-null  object
#  4   street_name          181262 non-null  object
#  5   storey_range         181262 non-null  object
#  6   floor_area_sqm       181262 non-null  float64
#  7   flat_model           181262 non-null  object
#  8   lease_commence_date  181262 non-null  int64
#  9   remaining_lease      181262 non-null  object
#  10  resale_price         181262 non-null  float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 15.2+ MB

# %%
pd.set_option('display.max_columns', None)

# for visualization
import matplotlib.pyplot as plt
import seaborn as sns

hdb_df = hdb_df.drop(hdb_df[['street_name', 'flat_model', 'block']], axis=1)

hdb_df
# Out:
#           month        town  flat_type storey_range  floor_area_sqm  \
# 0       2017-01  ANG MO KIO     2 ROOM     10 TO 12            44.0
# 1       2017-01  ANG MO KIO     3 ROOM     01 TO 03            67.0
# 2       2017-01  ANG MO KIO     3 ROOM     01 TO 03            67.0
# 3       2017-01  ANG MO KIO     3 ROOM     04 TO 06            68.0
# 4       2017-01  ANG MO KIO     3 ROOM     01 TO 03            67.0
# ...         ...         ...        ...          ...             ...
# 181257  2024-06      YISHUN     5 ROOM     10 TO 12           112.0
# 181258  2024-06      YISHUN     5 ROOM     07 TO 09           122.0
# 181259  2024-06      YISHUN  EXECUTIVE     10 TO 12           146.0
# 181260  2024-06      YISHUN  EXECUTIVE     10 TO 12           146.0
# 181261  2024-06      YISHUN  EXECUTIVE     04 TO 06           146.0
#
#         lease_commence_date     remaining_lease  resale_price
# 0                      1979  61 years 04 months      232000.0
# 1                      1978  60 years 07 months      250000.0
# 2                      1980  62 years 05 months      262000.0
# 3                      1980   62 years 01 month      265000.0
# 4                      1980  62 years 05 months      265000.0
# ...                     ...                 ...           ...
# 181257                 2018  92 years 08 months      738000.0
# 181258                 1988  62 years 10 months      680000.0
# 181259                 1986            61 years      790000.0
# 181260                 1988  62 years 08 months     1000000.0
# 181261                 1988  62 years 08 months     1000000.0
#
# [181262 rows x 8 columns]

# %%
# Outlier analysis on 'floor_area_sqm'

sns.boxplot(y='floor_area_sqm', data=hdb_df)
# Out:
# <Axes: ylabel='floor_area_sqm'>

# %%
hdb_df_above_186 = hdb_df[hdb_df['floor_area_sqm'] > 186]
hdb_df_above_186
# Out:
#           month             town  flat_type storey_range  floor_area_sqm  \
# 2187    2017-02        WOODLANDS  EXECUTIVE     10 TO 12           192.0
# 4060    2017-03        WOODLANDS  EXECUTIVE     07 TO 09           189.0
# 5890    2017-04        WOODLANDS  EXECUTIVE     07 TO 09           192.0
# 7854    2017-05        WOODLANDS  EXECUTIVE     10 TO 12           189.0
# 8868    2017-06  KALLANG/WHAMPOA     3 ROOM     01 TO 03           215.0
# ...         ...              ...        ...          ...             ...
# 169006  2023-12        WOODLANDS  EXECUTIVE     04 TO 06           192.0
# 171559  2024-01        WOODLANDS  EXECUTIVE     04 TO 06           192.0
# 172801  2024-02  KALLANG/WHAMPOA     3 ROOM     01 TO 03           208.0
# 175798  2024-03        WOODLANDS  EXECUTIVE     04 TO 06           189.0
# 179561  2024-05  KALLANG/WHAMPOA     3 ROOM     01 TO 03           189.4
#
#         lease_commence_date     remaining_lease  resale_price
# 2187                   1994  75 years 11 months      760000.0
# 4060                   1994   76 years 01 month      800000.0
# 5890                   1994  75 years 09 months      729000.0
# 7854                   1994  75 years 08 months      765000.0
# 8868                   1972   54 years 01 month      830000.0
# ...                     ...                 ...           ...
# 169006                 1994  69 years 02 months     1038000.0
# 171559                 1994  69 years 02 months      930000.0
# 172801                 1972  47 years 06 months     1280000.0
# 175798                 1994  69 years 03 months      980000.0
# 179561                 1972  47 years 03 months     1150000.0
#
# [135 rows x 8 columns]

# %%
hdb_df_below_90 = hdb_df[hdb_df['floor_area_sqm'] < 45]
hdb_df_below_90
# Out:
#           month         town flat_type storey_range  floor_area_sqm  \
# 0       2017-01   ANG MO KIO    2 ROOM     10 TO 12            44.0
# 195     2017-01  BUKIT MERAH    2 ROOM     07 TO 09            34.0
# 196     2017-01  BUKIT MERAH    2 ROOM     07 TO 09            34.0
# 383     2017-01      GEYLANG    2 ROOM     07 TO 09            42.0
# 384     2017-01      GEYLANG    2 ROOM     10 TO 12            42.0
# ...         ...          ...       ...          ...             ...
# 180896  2024-06  BUKIT MERAH    2 ROOM     07 TO 09            43.0
# 181013  2024-06  JURONG WEST    2 ROOM     10 TO 12            38.0
# 181065  2024-06      PUNGGOL    2 ROOM     19 TO 21            38.0
# 181102  2024-06    SEMBAWANG    2 ROOM     07 TO 09            38.0
# 181227  2024-06       YISHUN    2 ROOM     04 TO 06            38.0
#
#         lease_commence_date     remaining_lease  resale_price
# 0                      1979  61 years 04 months      232000.0
# 195                    1971  53 years 06 months      218000.0
# 196                    1971  53 years 06 months      230000.0
# 383                    1971            53 years      205000.0
# 384                    1971            53 years      215000.0
# ...                     ...                 ...           ...
# 180896                 1970  44 years 10 months      250000.0
# 181013                 2019            94 years      330000.0
# 181065                 2018  93 years 06 months      332000.0
# 181102                 2019            94 years      327000.0
# 181227                 2019  94 years 04 months      322888.0
#
# [841 rows x 8 columns]

# %%
# removing outliers by dropping the impacted rows

hdb_df = hdb_df.drop(index=hdb_df_above_186.index)
hdb_df
# Out:
#           month        town  flat_type storey_range  floor_area_sqm  \
# 0       2017-01  ANG MO KIO     2 ROOM     10 TO 12            44.0
# 1       2017-01  ANG MO KIO     3 ROOM     01 TO 03            67.0
# 2       2017-01  ANG MO KIO     3 ROOM     01 TO 03            67.0
# 3       2017-01  ANG MO KIO     3 ROOM     04 TO 06            68.0
# 4       2017-01  ANG MO KIO     3 ROOM     01 TO 03            67.0
# ...         ...         ...        ...          ...             ...
# 181257  2024-06      YISHUN     5 ROOM     10 TO 12           112.0
# 181258  2024-06      YISHUN     5 ROOM     07 TO 09           122.0
# 181259  2024-06      YISHUN  EXECUTIVE     10 TO 12           146.0
# 181260  2024-06      YISHUN  EXECUTIVE     10 TO 12           146.0
# 181261  2024-06      YISHUN  EXECUTIVE     04 TO 06           146.0
#
#         lease_commence_date     remaining_lease  resale_price
# 0                      1979  61 years 04 months      232000.0
# 1                      1978  60 years 07 months      250000.0
# 2                      1980  62 years 05 months      262000.0
# 3                      1980   62 years 01 month      265000.0
# 4                      1980  62 years 05 months      265000.0
# ...                     ...                 ...           ...
# 181257                 2018  92 years 08 months      738000.0
# 181258                 1988  62 years 10 months      680000.0
# 181259                 1986            61 years      790000.0
# 181260                 1988  62 years 08 months     1000000.0
# 181261                 1988  62 years 08 months     1000000.0
#
# [181127 rows x 8 columns]

# %%
# removing outliers by dropping the impacted rows

hdb_df = hdb_df.drop(index=hdb_df_below_90.index)
hdb_df
# Out:
#           month        town  flat_type storey_range  floor_area_sqm  \
# 1       2017-01  ANG MO KIO     3 ROOM     01 TO 03            67.0
# 2       2017-01  ANG MO KIO     3 ROOM     01 TO 03            67.0
# 3       2017-01  ANG MO KIO     3 ROOM     04 TO 06            68.0
# 4       2017-01  ANG MO KIO     3 ROOM     01 TO 03            67.0
# 5       2017-01  ANG MO KIO     3 ROOM     01 TO 03            68.0
# ...         ...         ...        ...          ...             ...
# 181257  2024-06      YISHUN     5 ROOM     10 TO 12           112.0
# 181258  2024-06      YISHUN     5 ROOM     07 TO 09           122.0
# 181259  2024-06      YISHUN  EXECUTIVE     10 TO 12           146.0
# 181260  2024-06      YISHUN  EXECUTIVE     10 TO 12           146.0
# 181261  2024-06      YISHUN  EXECUTIVE     04 TO 06           146.0
#
#         lease_commence_date     remaining_lease  resale_price
# 1                      1978  60 years 07 months      250000.0
# 2                      1980  62 years 05 months      262000.0
# 3                      1980   62 years 01 month      265000.0
# 4                      1980  62 years 05 months      265000.0
# 5                      1981            63 years      275000.0
# ...                     ...                 ...           ...
# 181257                 2018  92 years 08 months      738000.0
# 181258                 1988  62 years 10 months      680000.0
# 181259                 1986            61 years      790000.0
# 181260                 1988  62 years 08 months     1000000.0
# 181261                 1988  62 years 08 months     1000000.0
#
# [180286 rows x 8 columns]

# %%
# Outlier analysis on 'resale_price'

sns.boxplot(y='resale_price', data=hdb_df)
# Out:
# <Axes: ylabel='resale_price'>

# %%
# Calculate Q1 and Q3
q1 = hdb_df['resale_price'].quantile(0.25)
q3 = hdb_df['resale_price'].quantile(0.75)

# Calculate the Interquartile Range (IQR)
iqr = q3 - q1

# Calculate the upper boundary for outliers
upper_boundary = q3 + 1.5 * iqr
upper_boundary
# Out:
# 927500.0

# %%
hdb_df_above_up = hdb_df[hdb_df['resale_price'] > 927500]
hdb_df_above_up
# Out:
#           month             town  flat_type storey_range  floor_area_sqm  \
# 310     2017-01     CENTRAL AREA     5 ROOM     49 TO 51           105.0
# 664     2017-01  KALLANG/WHAMPOA     5 ROOM     25 TO 27           119.0
# 1329    2017-02           BISHAN     5 ROOM     40 TO 42           120.0
# 1397    2017-02      BUKIT MERAH     5 ROOM     19 TO 21           115.0
# 1398    2017-02      BUKIT MERAH     5 ROOM     34 TO 36           114.0
# ...         ...              ...        ...          ...             ...
# 181178  2024-06         TAMPINES  EXECUTIVE     01 TO 03           146.0
# 181195  2024-06        TOA PAYOH     4 ROOM     16 TO 18            93.0
# 181197  2024-06        TOA PAYOH     5 ROOM     13 TO 15           153.0
# 181260  2024-06           YISHUN  EXECUTIVE     10 TO 12           146.0
# 181261  2024-06           YISHUN  EXECUTIVE     04 TO 06           146.0
#
#         lease_commence_date     remaining_lease  resale_price
# 310                    2011            93 years     1108000.0
# 664                    2011            93 years     1005000.0
# 1329                   2011  93 years 07 months     1180000.0
# 1397                   2013  95 years 03 months      955000.0
# 1398                   2013  95 years 03 months      980000.0
# ...                     ...                 ...           ...
# 181178                 1989            64 years      960000.0
# 181195                 2019  94 years 08 months      940000.0
# 181197                 1984  59 years 02 months     1130000.0
# 181260                 1988  62 years 08 months     1000000.0
# 181261                 1988  62 years 08 months     1000000.0
#
# [3858 rows x 8 columns]

# %%
hdb_df['resale_price'].max()
# Out:
# 1588000.0

# %%
# redefining 'remaining_lease' feature from years and months into months.
# creating a new feature column 'lease_remaining'

def convert_to_months(remaining_lease):
    parts = remaining_lease.split()
    years = 0
    months = 0

    for i in range(len(parts)):
        if 'year' in parts[i]:
            years = int(parts[i-1])
        elif 'month' in parts[i]:
            months = int(parts[i-1])
       
    total_months = years * 12 + months
    return total_months

hdb_df['lease_remaining'] = hdb_df['remaining_lease'].apply(convert_to_months)
  
hdb_df = hdb_df.drop('remaining_lease', axis=1)

hdb_df
# Out:
#           month        town  flat_type storey_range  floor_area_sqm  \
# 1       2017-01  ANG MO KIO     3 ROOM     01 TO 03            67.0
# 2       2017-01  ANG MO KIO     3 ROOM     01 TO 03            67.0
# 3       2017-01  ANG MO KIO     3 ROOM     04 TO 06            68.0
# 4       2017-01  ANG MO KIO     3 ROOM     01 TO 03            67.0
# 5       2017-01  ANG MO KIO     3 ROOM     01 TO 03            68.0
# ...         ...         ...        ...          ...             ...
# 181257  2024-06      YISHUN     5 ROOM     10 TO 12           112.0
# 181258  2024-06      YISHUN     5 ROOM     07 TO 09           122.0
# 181259  2024-06      YISHUN  EXECUTIVE     10 TO 12           146.0
# 181260  2024-06      YISHUN  EXECUTIVE     10 TO 12           146.0
# 181261  2024-06      YISHUN  EXECUTIVE     04 TO 06           146.0
#
#         lease_commence_date  resale_price  lease_remaining
# 1                      1978      250000.0              727
# 2                      1980      262000.0              749
# 3                      1980      265000.0              745
# 4                      1980      265000.0              749
# 5                      1981      275000.0              756
# ...                     ...           ...              ...
# 181257                 2018      738000.0             1112
# 181258                 1988      680000.0              754
# 181259                 1986      790000.0              732
# 181260                 1988     1000000.0              752
# 181261                 1988     1000000.0              752
#
# [180286 rows x 8 columns]

# %%
# check if any of lease remaining is above 1188 months ie greater than 99 years

hdb_df_above_1188 = hdb_df[hdb_df['lease_remaining'] > 1188]
display(len(hdb_df_above_1188))
# Out:
# 0

# %%
sns.pairplot(hdb_df)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
display(hdb_df)
# Out:
#           month        town  flat_type storey_range  floor_area_sqm  \
# 1       2017-01  ANG MO KIO     3 ROOM     01 TO 03            67.0
# 2       2017-01  ANG MO KIO     3 ROOM     01 TO 03            67.0
# 3       2017-01  ANG MO KIO     3 ROOM     04 TO 06            68.0
# 4       2017-01  ANG MO KIO     3 ROOM     01 TO 03            67.0
# 5       2017-01  ANG MO KIO     3 ROOM     01 TO 03            68.0
# ...         ...         ...        ...          ...             ...
# 181257  2024-06      YISHUN     5 ROOM     10 TO 12           112.0
# 181258  2024-06      YISHUN     5 ROOM     07 TO 09           122.0
# 181259  2024-06      YISHUN  EXECUTIVE     10 TO 12           146.0
# 181260  2024-06      YISHUN  EXECUTIVE     10 TO 12           146.0
# 181261  2024-06      YISHUN  EXECUTIVE     04 TO 06           146.0
#
#         lease_commence_date  resale_price  lease_remaining
# 1                      1978      250000.0              727
# 2                      1980      262000.0              749
# 3                      1980      265000.0              745
# 4                      1980      265000.0              749
# 5                      1981      275000.0              756
# ...                     ...           ...              ...
# 181257                 2018      738000.0             1112
# 181258                 1988      680000.0              754
# 181259                 1986      790000.0              732
# 181260                 1988     1000000.0              752
# 181261                 1988     1000000.0              752
#
# [180286 rows x 8 columns]

# %%
# dropping the 'month' and 'lease_commence_date' from dataset

hdb_df = hdb_df.drop(['month', 'lease_commence_date'], axis=1)
hdb_df
# Out:
#               town  flat_type storey_range  floor_area_sqm  resale_price  \
# 1       ANG MO KIO     3 ROOM     01 TO 03            67.0      250000.0
# 2       ANG MO KIO     3 ROOM     01 TO 03            67.0      262000.0
# 3       ANG MO KIO     3 ROOM     04 TO 06            68.0      265000.0
# 4       ANG MO KIO     3 ROOM     01 TO 03            67.0      265000.0
# 5       ANG MO KIO     3 ROOM     01 TO 03            68.0      275000.0
# ...            ...        ...          ...             ...           ...
# 181257      YISHUN     5 ROOM     10 TO 12           112.0      738000.0
# 181258      YISHUN     5 ROOM     07 TO 09           122.0      680000.0
# 181259      YISHUN  EXECUTIVE     10 TO 12           146.0      790000.0
# 181260      YISHUN  EXECUTIVE     10 TO 12           146.0     1000000.0
# 181261      YISHUN  EXECUTIVE     04 TO 06           146.0     1000000.0
#
#         lease_remaining
# 1                   727
# 2                   749
# 3                   745
# 4                   749
# 5                   756
# ...                 ...
# 181257             1112
# 181258              754
# 181259              732
# 181260              752
# 181261              752
#
# [180286 rows x 6 columns]

# %%
hdb_df.describe()
# Out:
#        floor_area_sqm  resale_price  lease_remaining
# count   180286.000000  1.802860e+05    180286.000000
# mean        97.344420  4.987337e+05       895.699084
# std         23.628913  1.718718e+05       167.015426
# min         45.000000  1.400000e+05       498.000000
# 25%         82.000000  3.700000e+05       759.000000
# 50%         93.000000  4.688880e+05       894.000000
# 75%        112.000000  5.930000e+05      1060.000000
# max        186.000000  1.588000e+06      1173.000000

# %%
# barchart comparing mean prices of 'flat_type' by 'town'

mean_resale_price = hdb_df.groupby(['town', 'flat_type'])['resale_price'].mean().unstack()

towns = mean_resale_price.index

for town in towns:
    plt.figure(figsize=(5, 3))
    mean_resale_price.loc[town].plot(kind='bar')
    plt.title(f'Mean Resale Price for {town}')
    plt.xlabel('Flat Type')
    plt.ylabel('Mean Resale Price')
    plt.xticks(rotation=45)
    plt.show()

# %%
hdb_df['storey_range'].value_counts()
# Out:
# storey_range
# 04 TO 06    41468
# 07 TO 09    37832
# 10 TO 12    33602
# 01 TO 03    31766
# 13 TO 15    17311
# 16 TO 18     8126
# 19 TO 21     3497
# 22 TO 24     2487
# 25 TO 27     1505
# 28 TO 30      979
# 31 TO 33      524
# 34 TO 36      470
# 37 TO 39      406
# 40 TO 42      196
# 43 TO 45       57
# 46 TO 48       45
# 49 TO 51       15
# Name: count, dtype: int64

# %%
hdb_df['flat_type'].value_counts()
# Out:
# flat_type
# 4 ROOM              76457
# 5 ROOM              45059
# 3 ROOM              42900
# EXECUTIVE           13347
# 2 ROOM               2445
# MULTI-GENERATION       78
# Name: count, dtype: int64

# %%
hdb_df['town'].value_counts()
# Out:
# town
# SENGKANG           14963
# PUNGGOL            13392
# WOODLANDS          12722
# YISHUN             12370
# TAMPINES           12139
# JURONG WEST        11967
# BEDOK               9608
# HOUGANG             9134
# CHOA CHU KANG       8291
# ANG MO KIO          7358
# BUKIT BATOK         6906
# BUKIT MERAH         6829
# BUKIT PANJANG       6664
# TOA PAYOH           5528
# KALLANG/WHAMPOA     5423
# PASIR RIS           5387
# QUEENSTOWN          4996
# SEMBAWANG           4914
# GEYLANG             4365
# CLEMENTI            4061
# JURONG EAST         3676
# SERANGOON           3293
# BISHAN              3271
# CENTRAL AREA        1461
# MARINE PARADE       1112
# BUKIT TIMAH          456
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the LabelEncoder
le = LabelEncoder()

# Fit and transform the categorical variable
hdb_df['flat_type'] = le.fit_transform(hdb_df['flat_type'])
hdb_df
# Out:
#               town  flat_type storey_range  floor_area_sqm  resale_price  \
# 1       ANG MO KIO          1     01 TO 03            67.0      250000.0
# 2       ANG MO KIO          1     01 TO 03            67.0      262000.0
# 3       ANG MO KIO          1     04 TO 06            68.0      265000.0
# 4       ANG MO KIO          1     01 TO 03            67.0      265000.0
# 5       ANG MO KIO          1     01 TO 03            68.0      275000.0
# ...            ...        ...          ...             ...           ...
# 181257      YISHUN          3     10 TO 12           112.0      738000.0
# 181258      YISHUN          3     07 TO 09           122.0      680000.0
# 181259      YISHUN          4     10 TO 12           146.0      790000.0
# 181260      YISHUN          4     10 TO 12           146.0     1000000.0
# 181261      YISHUN          4     04 TO 06           146.0     1000000.0
#
#         lease_remaining
# 1                   727
# 2                   749
# 3                   745
# 4                   749
# 5                   756
# ...                 ...
# 181257             1112
# 181258              754
# 181259              732
# 181260              752
# 181261              752
#
# [180286 rows x 6 columns]

# %%
hdb_df['storey_range'] = le.fit_transform(hdb_df['storey_range'])
hdb_df
# Out:
#               town  flat_type  storey_range  floor_area_sqm  resale_price  \
# 1       ANG MO KIO          1             0            67.0      250000.0
# 2       ANG MO KIO          1             0            67.0      262000.0
# 3       ANG MO KIO          1             1            68.0      265000.0
# 4       ANG MO KIO          1             0            67.0      265000.0
# 5       ANG MO KIO          1             0            68.0      275000.0
# ...            ...        ...           ...             ...           ...
# 181257      YISHUN          3             3           112.0      738000.0
# 181258      YISHUN          3             2           122.0      680000.0
# 181259      YISHUN          4             3           146.0      790000.0
# 181260      YISHUN          4             3           146.0     1000000.0
# 181261      YISHUN          4             1           146.0     1000000.0
#
#         lease_remaining
# 1                   727
# 2                   749
# 3                   745
# 4                   749
# 5                   756
# ...                 ...
# 181257             1112
# 181258              754
# 181259              732
# 181260              752
# 181261              752
#
# [180286 rows x 6 columns]

# %%
hdb_df['town'] = le.fit_transform(hdb_df['town'])
hdb_df
# Out:
#         town  flat_type  storey_range  floor_area_sqm  resale_price  \
# 1          0          1             0            67.0      250000.0
# 2          0          1             0            67.0      262000.0
# 3          0          1             1            68.0      265000.0
# 4          0          1             0            67.0      265000.0
# 5          0          1             0            68.0      275000.0
# ...      ...        ...           ...             ...           ...
# 181257    25          3             3           112.0      738000.0
# 181258    25          3             2           122.0      680000.0
# 181259    25          4             3           146.0      790000.0
# 181260    25          4             3           146.0     1000000.0
# 181261    25          4             1           146.0     1000000.0
#
#         lease_remaining
# 1                   727
# 2                   749
# 3                   745
# 4                   749
# 5                   756
# ...                 ...
# 181257             1112
# 181258              754
# 181259              732
# 181260              752
# 181261              752
#
# [180286 rows x 6 columns]
